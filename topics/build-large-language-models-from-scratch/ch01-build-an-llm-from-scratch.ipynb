# %% [markdown]
# ## 1. Dev Enviroment Setup
#
# Guide for installing PyTorch:
# https://pytorch.org/get-started/locally/
#
# For a using PyTorch with Mac GPUs:
# https://pytorch.org/blog/running-pytorch-models-on-apple-silicon-gpus-with-the-executorch-mlx-delegate/

# %%
# Python 3.x
# !uv pip install torch torchvision
# Out:
# Using Python 3.13.9 environment at: /Users/jaysilvas/.venv/notebook-base
# Audited 2 packages in 48ms

# %%
# Check for Apple silicon (M Series) compatibility
print(torch.backends.mps.is_available())
# Out:
# True

# %%
# Quick PyTorch example verification
import torch
x = torch.rand(5, 3)
print(x)

#Results should be a 5x3 matrix of random numbers between 0 and 1, like this:
''' 
tensor([[0.8563, 0.8961, 0.0135],
        [0.4649, 0.0771, 0.6425],
        [0.0026, 0.3792, 0.0139],
        [0.0505, 0.8831, 0.2008],
        [0.2033, 0.9472, 0.1155]])
'''
# Out:
# tensor([[0.6989, 0.5239, 0.7130],
#         [0.3777, 0.9883, 0.8519],
#         [0.0883, 0.2258, 0.7403],
#         [0.5676, 0.4713, 0.8187],
#         [0.3360, 0.0771, 0.7364]])
# ' \ntensor([[0.8563, 0.8961, 0.0135],\n        [0.4649, 0.0771, 0.6425],\n        [0.0026, 0.3792, 0.0139],\n        [0.0505, 0.8831, 0.2008],\n        [0.2033, 0.9472, 0.1155]])\n'

# %% [markdown]
# For further study on PyTorch, check out the Quick Start docs: https://docs.pytorch.org/tutorials/beginner/basics/quickstart_tutorial.html

# %% [markdown]
# ## 2. LLM Implementation Process
#
# ![image.png](attachment:image.png)
